# %%
import nltk
import numpy as np
import random
import string
import bs4 as bs
import requests
import re
import warnings

# %%
warnings.filterwarnings = False

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-24de421fef12> in <module>
# ----> 1 from sklearn.feature_extraction.text import TfidfVectorizer
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/__init__.py in <module>
#      78     from . import _distributor_init  # noqa: F401
#      79     from . import __check_build  # noqa: F401
# ---> 80     from .base import clone
#      81     from .utils._show_versions import show_versions
#      82
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/base.py in <module>
#      19 from . import __version__
#      20 from ._config import get_config
# ---> 21 from .utils import _IS_32BIT
#      22 from .utils.validation import check_X_y
#      23 from .utils.validation import check_array
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/__init__.py in <module>
#      21
#      22 from .murmurhash import murmurhash3_32
# ---> 23 from .class_weight import compute_class_weight, compute_sample_weight
#      24 from . import _joblib
#      25 from ..exceptions import DataConversionWarning
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/class_weight.py in <module>
#       5 import numpy as np
#       6
# ----> 7 from .validation import _deprecate_positional_args
#       8
#       9
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in <module>
#      23 from contextlib import suppress
#      24
# ---> 25 from .fixes import _object_dtype_isnan, parse_version
#      26 from .. import get_config as _get_config
#      27 from ..exceptions import NonBLASDotWarning, PositiveSpectrumWarning
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/fixes.py in <module>
#      16 import scipy.sparse as sp
#      17 import scipy
# ---> 18 import scipy.stats
#      19 from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#      20 from numpy.ma import MaskedArray as _MaskedArray  # TODO: remove in 0.25
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/__init__.py in <module>
#     341 from __future__ import division, print_function, absolute_import
#     342
# --> 343 from .stats import *
#     344 from .distributions import *
#     345 from .morestats import *
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py in <module>
#     167 from scipy._lib.six import callable, string_types
#     168 from scipy._lib._version import NumpyVersion
# --> 169 import scipy.special as special
#     170 import scipy.linalg as linalg
#     171 from . import distributions
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/special/__init__.py in <module>
#     640 from ._ufuncs import *
#     641
# --> 642 from .basic import *
#     643 from ._logsumexp import logsumexp
#     644 from . import specfun
#
# ~/opt/anaconda3/lib/python3.7/site-packages/scipy/special/basic.py in <module>
#      16                       psi, _zeta, hankel1, hankel2, yv, kv, ndtri,
#      17                       poch, binom, hyp0f1)
# ---> 18 from . import specfun
#      19 from . import orthogonal
#      20 from ._comb import _comb_int
#
# ImportError: dlopen(/Users/apple/opt/anaconda3/lib/python3.7/site-packages/scipy/special/specfun.cpython-37m-darwin.so, 2): Symbol not found: _PyNumber_Int
#   Referenced from: /Users/apple/opt/anaconda3/lib/python3.7/site-packages/scipy/special/specfun.cpython-37m-darwin.so
#   Expected in: flat namespace
#  in /Users/apple/opt/anaconda3/lib/python3.7/site-packages/scipy/special/specfun.cpython-37m-darwin.so

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::datashader==0.11.1=py_0
#   - defaults/osx-64::zope.interface==5.1.0=py37haf1e3a3_0
#   - defaults/noarch::prompt_toolkit==2.0.10=py_0
#   - defaults/osx-64::pyproj==1.9.6=py37h9c430a6_0
#   - defaults/noarch::owslib==0.18.0=py_0
#   - defaults/osx-64::pytest-astropy==0.5.0=py37_0
#   - defaults/noarch::pygments==2.4.2=py_0
#   - defaults/osx-64::cftime==1.2.1=py37hf1fa96c_0
#   - defaults/osx-64::imageio==2.6.0=py37_0
#   - defaults/noarch::colorcet==2.0.2=py_0
#   - defaults/osx-64::pyct==0.4.6=py37_0
#   - defaults/noarch::flask==1.1.1=py_0
#   - defaults/osx-64::jupyter==1.0.0=py37_7
#   - defaults/osx-64::pytables==3.5.2=py37h5bccee9_1
#   - defaults/osx-64::sympy==1.4=py37_0
#   - defaults/osx-64::bcrypt==3.2.0=py37haf1e3a3_0
#   - defaults/osx-64::widgetsnbextension==3.5.1=py37_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.1=py_0
#   - defaults/osx-64::setuptools==41.4.0=py37_0
#   - defaults/noarch::numpydoc==0.9.1=py_0
#   - defaults/osx-64::nose==1.3.7=py37_2
#   - defaults/osx-64::conda-package-handling==1.6.1=py37h1de35cc_0
#   - defaults/osx-64::fiona==1.8.4=py37h9a122fd_0
#   - pyviz/noarch::holoviews==1.12.7=py_0
#   - defaults/osx-64::pytest==5.2.1=py37_0
#   - conda-forge/osx-64::selenium==3.141.0=py37h9bfed18_1001
#   - defaults/osx-64::parsel==1.5.2=py37_0
#   - defaults/osx-64::clyent==1.2.2=py37_1
#   - defaults/noarch::anaconda-project==0.8.3=py_0
#   - defaults/osx-64::bottleneck==1.2.1=py37h1d22016_1
#   - defaults/osx-64::ipython==7.8.0=py37h39e3cac_0
#   - defaults/osx-64::wheel==0.33.6=py37_0
#   - defaults/osx-64::shapely==1.6.4=py37he8793f5_0
#   - defaults/osx-64::pytest-arraydiff==0.3=py37h39e3cac_0
#   - defaults/noarch::ipywidgets==7.5.1=py_0
#   - defaults/noarch::xarray==0.16.0=py_0
#   - defaults/noarch::pytest-runner==5.2=py_0
#   - defaults/osx-64::conda-build==3.20.1=py37_0
#   - defaults/osx-64::numexpr==2.7.0=py37h7413580_0
#   - defaults/osx-64::pyepsg==0.4.0=py37_0
#   - defaults/osx-64::anaconda-navigator==1.9.12=py37_0
#   - defaults/noarch::sphinx==2.2.0=py_0
#   - conda-forge/osx-64::scrapy==2.0.1=py37hc8dfbb8_0
#   - defaults/osx-64::bkcharts==0.2=py37_0
#   - defaults/osx-64::cligj==0.5.0=py37_0
#   - defaults/osx-64::h5py==2.9.0=py37h3134771_0
#   - defaults/noarch::jupyterlab_server==1.0.6=py_0
#   - defaults/osx-64::conda==4.8.4=py37_0
#   - defaults/osx-64::netcdf4==1.4.2=py37h13743db_0
#   - esri/osx-64::arcgis==1.6.0=py37h39e3cac_1
#   - defaults/noarch::geopandas==0.6.1=py_0
#   - defaults/osx-64::astroid==2.3.1=py37_0
#   - defaults/noarch::qtconsole==4.5.5=py_0
#   - pyviz/noarch::geoviews==1.6.6=py_0
#   - defaults/noarch::munch==2.5.0=py_0
#   - defaults/osx-64::service_identity==18.1.0=py37h28b3542_0
#   - defaults/noarch::jupyterlab==1.1.4=pyhf63ae98_0
#   - defaults/osx-64::anaconda==2019.10=py37_0
#   - defaults/osx-64::cartopy==0.17.0=py37haea56ea_1
#   - defaults/osx-64::pylint==2.4.2=py37_0
#   - defaults/osx-64::spyder-kernels==0.5.2=py37_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/osx-64::twisted==20.3.0=py37h1de35cc_0
#   - defaults/osx-64::gdal==2.3.3=py37hbe65578_0
#   - defaults/osx-64::isort==4.3.21=py37_0
#   - pyviz/noarch::geoviews-core==1.6.6=py_0
#   - defaults/osx-64::jupyter_console==6.0.0=py37_0
#   - defaults/osx-64::mkl_fft==1.0.14=py37h5e564d8_0
#   - defaults/osx-64::jsonschema==3.0.2=py37_0
#   - defaults/osx-64::datashape==0.5.4=py37_1
#   - defaults/osx-64::urllib3==1.24.2=py37_0
#   - defaults/noarch::pytest-openfiles==0.4.0=py_0
#   - defaults/osx-64::statsmodels==0.10.1=py37h1d22016_0
#   - defaults/osx-64::bleach==3.1.0=py37_0
#   - defaults/osx-64::pykdtree==1.3.1=py37h1d22016_2
#   - defaults/osx-64::bokeh==1.3.4=py37_0
#   - defaults/osx-64::numpy==1.17.2=py37h99e6662_0
#   - defaults/osx-64::anaconda-client==1.7.2=py37_0
#   - defaults/osx-64::pytest-remotedata==0.3.2=py37_0
#   - defaults/noarch::click-plugins==1.1.1=py_0
#   - defaults/osx-64::patsy==0.5.1=py37_0
#   - defaults/osx-64::notebook==6.0.1=py37_0
#   - defaults/noarch::distributed==2.5.2=py_0
#   - defaults/noarch::pytest-doctestplus==0.4.0=py_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py37_0
#   - defaults/osx-64::nbconvert==5.6.0=py37_1
#   - defaults/osx-64::mkl_random==1.1.0=py37ha771720_0
#   - defaults/osx-64::astropy==3.2.2=py37h1de35cc_0
#   - defaults/osx-64::ipykernel==5.1.2=py37h39e3cac_0
#   - defaults/osx-64::spyder==3.3.6=py37_0
#   - defaults/noarch::dask==2.5.2=py_0
#   - defaults/osx-64::nbformat==4.4.0=py37_0
#   - pyviz/noarch::panel==0.6.4=py_0
#   - defaults/osx-64::cython==0.29.13=py37h0a44026_0
#   - defaults/noarch::automat==0.8.0=py_0
#   - defaults/osx-64::numba==0.45.1=py37h6440ff4_0
# failed with repodata from current_repodata.json, will retry with next repodata source.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::datashader==0.11.1=py_0
#   - defaults/osx-64::zope.interface==5.1.0=py37haf1e3a3_0
#   - defaults/noarch::prompt_toolkit==2.0.10=py_0
#   - defaults/osx-64::pyproj==1.9.6=py37h9c430a6_0
#   - defaults/noarch::owslib==0.18.0=py_0
#   - defaults/osx-64::pytest-astropy==0.5.0=py37_0
#   - defaults/noarch::pygments==2.4.2=py_0
#   - defaults/osx-64::cftime==1.2.1=py37hf1fa96c_0
#   - defaults/osx-64::imageio==2.6.0=py37_0
#   - defaults/noarch::colorcet==2.0.2=py_0
#   - defaults/osx-64::pyct==0.4.6=py37_0
#   - defaults/noarch::flask==1.1.1=py_0
#   - defaults/osx-64::jupyter==1.0.0=py37_7
#   - defaults/osx-64::pytables==3.5.2=py37h5bccee9_1
#   - defaults/osx-64::sympy==1.4=py37_0
#   - defaults/osx-64::bcrypt==3.2.0=py37haf1e3a3_0
#   - defaults/osx-64::widgetsnbextension==3.5.1=py37_0
#   - defaults/noarch::backports.functools_lru_cache==1.6.1=py_0
#   - defaults/osx-64::setuptools==41.4.0=py37_0
#   - defaults/noarch::numpydoc==0.9.1=py_0
#   - defaults/osx-64::nose==1.3.7=py37_2
#   - defaults/osx-64::conda-package-handling==1.6.1=py37h1de35cc_0
#   - defaults/osx-64::fiona==1.8.4=py37h9a122fd_0
#   - pyviz/noarch::holoviews==1.12.7=py_0
#   - defaults/osx-64::pytest==5.2.1=py37_0
#   - conda-forge/osx-64::selenium==3.141.0=py37h9bfed18_1001
#   - defaults/osx-64::parsel==1.5.2=py37_0
#   - defaults/osx-64::clyent==1.2.2=py37_1
#   - defaults/noarch::anaconda-project==0.8.3=py_0
#   - defaults/osx-64::bottleneck==1.2.1=py37h1d22016_1
#   - defaults/osx-64::ipython==7.8.0=py37h39e3cac_0
#   - defaults/osx-64::wheel==0.33.6=py37_0
#   - defaults/osx-64::shapely==1.6.4=py37he8793f5_0
#   - defaults/osx-64::pytest-arraydiff==0.3=py37h39e3cac_0
#   - defaults/noarch::ipywidgets==7.5.1=py_0
#   - defaults/noarch::xarray==0.16.0=py_0
#   - defaults/noarch::pytest-runner==5.2=py_0
#   - defaults/osx-64::conda-build==3.20.1=py37_0
#   - defaults/osx-64::numexpr==2.7.0=py37h7413580_0
#   - defaults/osx-64::pyepsg==0.4.0=py37_0
#   - defaults/osx-64::anaconda-navigator==1.9.12=py37_0
#   - defaults/noarch::sphinx==2.2.0=py_0
#   - conda-forge/osx-64::scrapy==2.0.1=py37hc8dfbb8_0
#   - defaults/osx-64::bkcharts==0.2=py37_0
#   - defaults/osx-64::cligj==0.5.0=py37_0
#   - defaults/osx-64::h5py==2.9.0=py37h3134771_0
#   - defaults/noarch::jupyterlab_server==1.0.6=py_0
#   - defaults/osx-64::conda==4.8.4=py37_0
#   - defaults/osx-64::netcdf4==1.4.2=py37h13743db_0
#   - esri/osx-64::arcgis==1.6.0=py37h39e3cac_1
#   - defaults/noarch::geopandas==0.6.1=py_0
#   - defaults/osx-64::astroid==2.3.1=py37_0
#   - defaults/noarch::qtconsole==4.5.5=py_0
#   - pyviz/noarch::geoviews==1.6.6=py_0
#   - defaults/noarch::munch==2.5.0=py_0
#   - defaults/osx-64::service_identity==18.1.0=py37h28b3542_0
#   - defaults/noarch::jupyterlab==1.1.4=pyhf63ae98_0
#   - defaults/osx-64::anaconda==2019.10=py37_0
#   - defaults/osx-64::cartopy==0.17.0=py37haea56ea_1
#   - defaults/osx-64::pylint==2.4.2=py37_0
#   - defaults/osx-64::spyder-kernels==0.5.2=py37_0
#   - defaults/noarch::conda-verify==3.4.2=py_1
#   - defaults/osx-64::twisted==20.3.0=py37h1de35cc_0
#   - defaults/osx-64::gdal==2.3.3=py37hbe65578_0
#   - defaults/osx-64::isort==4.3.21=py37_0
#   - pyviz/noarch::geoviews-core==1.6.6=py_0
#   - defaults/osx-64::jupyter_console==6.0.0=py37_0
#   - defaults/osx-64::mkl_fft==1.0.14=py37h5e564d8_0
#   - defaults/osx-64::jsonschema==3.0.2=py37_0
#   - defaults/osx-64::datashape==0.5.4=py37_1
#   - defaults/osx-64::urllib3==1.24.2=py37_0
#   - defaults/noarch::pytest-openfiles==0.4.0=py_0
#   - defaults/osx-64::statsmodels==0.10.1=py37h1d22016_0
#   - defaults/osx-64::bleach==3.1.0=py37_0
#   - defaults/osx-64::pykdtree==1.3.1=py37h1d22016_2
#   - defaults/osx-64::bokeh==1.3.4=py37_0
#   - defaults/osx-64::numpy==1.17.2=py37h99e6662_0
#   - defaults/osx-64::anaconda-client==1.7.2=py37_0
#   - defaults/osx-64::pytest-remotedata==0.3.2=py37_0
#   - defaults/noarch::click-plugins==1.1.1=py_0
#   - defaults/osx-64::patsy==0.5.1=py37_0
#   - defaults/osx-64::notebook==6.0.1=py37_0
#   - defaults/noarch::distributed==2.5.2=py_0
#   - defaults/noarch::pytest-doctestplus==0.4.0=py_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py37_0
#   - defaults/osx-64::nbconvert==5.6.0=py37_1
#   - defaults/osx-64::mkl_random==1.1.0=py37ha771720_0
#   - defaults/osx-64::astropy==3.2.2=py37h1de35cc_0
#   - defaults/osx-64::ipykernel==5.1.2=py37h39e3cac_0
#   - defaults/osx-64::spyder==3.3.6=py37_0
#   - defaults/noarch::dask==2.5.2=py_0
#   - defaults/osx-64::nbformat==4.4.0=py37_0
#   - pyviz/noarch::panel==0.6.4=py_0
#   - defaults/osx-64::cython==0.29.13=py37h0a44026_0
#   - defaults/noarch::automat==0.8.0=py_0
#   - defaults/osx-64::numba==0.45.1=py37h6440ff4_0
# -
